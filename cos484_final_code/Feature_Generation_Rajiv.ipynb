# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/COS484
# Out:
# /content/drive/.shortcut-targets-by-id/1ivSpBtqx8LrribtrT2jDiKW444CtGD-B/COS484

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1ivSpBtqx8LrribtrT2jDiKW444CtGD-B/COS484

# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.0.0+cu118
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: filelock, jinja2, networkx, sympy, triton, typing-extensions
# Required-by: fastai, torchaudio, torchdata, torchtext, torchvision, triton

# %%
# !pip install transformers
# !pip install nltk
# !pip install fasttext
# !pip install pyarrow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # **Create Features**

# %%
# !python create_features.py --exp_config generator_config/electra_exp_config.yaml
# Out:
# 2023-05-04 01:57:56.226691: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# # **Run Classifier**

# %%
# !python run.py --data_dir spouse --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/new-electra-mnli-exp-features-adam --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/electra-mnli-exp-adam --seed 76
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %% [markdown]
# # **Random Features**

# %%
# !python create_features.py --exp_config generator_config/electra_randomexp_config.yaml
# Out:
# 2023-05-04 01:20:16.056079: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# # **Run Classification**

# %%
# !python run.py --data_dir spouse --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-electra-random --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/electra-mnli-random-exp --seed 42
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
import torch
features = torch.load("spouse/new_features/spouse-electra-mnli-randomV2/train.bin")
features.shape
# Out:
# (22055, 41, 768)

# %% [markdown]
# # Running Disease

# %%
# !python run.py --data_dir disease --seed 42 --train --num_train_epochs 100 --task_name disease --classifier_type feature_concat --exp_dir input-features --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/disease-electramed-exp-ameya --feature_dim 768
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir disease --seed 69 --train --num_train_epochs 100 --task_name disease --classifier_type feature_concat --exp_dir input-features --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/disease-electramed-exp-ameya --feature_dim 768
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir disease --seed 123 --train --num_train_epochs 100 --task_name disease --classifier_type feature_concat --exp_dir input-features --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/disease-electramed-exp-ameya --feature_dim 768
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir disease --seed 420 --train --num_train_epochs 100 --task_name disease --classifier_type feature_concat --exp_dir input-features --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/disease-electramed-exp-ameya --feature_dim 768
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir disease --seed 76 --train --num_train_epochs 100 --task_name disease --classifier_type feature_concat --exp_dir input-features --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/disease-electramed-exp-ameya --feature_dim 768
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...
