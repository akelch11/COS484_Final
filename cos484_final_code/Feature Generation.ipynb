# %%
# %cd /content/drive/MyDrive/COS484
# Out:
# /content/drive/MyDrive/COS484

# %%
# !pip install transformers
# !pip install nltk
# !pip install fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 84.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 29.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 95.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pybind11-2.10.4-py3-none-any.whl (222 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4393308 sha256=f0f499e190fdf699522a6bd479593f91b43feba990f7a5aec14d08c4829c69c1
# ...

# %% [markdown]
# # **Create Features**

# %%
# !python create_features.py --exp_config generator_config/bert_randomexp_config.yaml
# Out:
# 2023-05-09 06:39:27.037219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %% [markdown]
# # **Run Classifier**

# %%
# !python run.py --data_dir spouse --seed 10 --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-bert-mnli-randomV2 --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/spouse-bert-mnli-randomV2
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir spouse --seed 15 --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-bert-mnli-randomV2 --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/spouse-bert-mnli-randomV2
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir spouse --seed 20 --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-bert-mnli-randomV2 --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/spouse-bert-mnli-randomV2
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir spouse --seed 25 --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-bert-mnli-randomV2 --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/spouse-bert-mnli-randomV2
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...

# %%
# !python run.py --data_dir spouse --seed 30 --train --num_train_epochs 100 --task_name spouse --classifier_type feature_concat --exp_dir new_features/spouse-bert-mnli-randomV2 --num_classes 2 --train_distributed 0 --dev_distributed 0 --save_model --output_dir outputs/spouse-bert-mnli-randomV2
# Out:
# Namespace(train=True, eval=False, seed=1102, data_dir='combined/spouse', output_dir='checkpoints/spouse_expbert', exp_dir='expbert-features', feat_dir='', percent_train=1.0, train_distributed=10, dev_distributed=0, num_classes=2, train_file='train.txt', dev_file='dev.txt', hidden_dim=64, num_layers=0, dropout=0.0, feature_dim=768, projection_dim=64, hyperparam_config='', learning_rate=0.001, train_batch_size=32, num_train_epochs=100, max_grad_norm=10.0, weight_decay=0.0, classifier_type='feature_concat', task_name='spouse', save_model=True, exp_list=[], keep=False, device=device(type='cpu'), n_gpu=0, num_explanations=41, regex_features=0, train_bin_file=['expbert-features/train_0.bin', 'expbert-features/train_1.bin', 'expbert-features/train_2.bin', 'expbert-features/train_3.bin', 'expbert-features/train_4.bin', 'expbert-features/train_5.bin', 'expbert-features/train_6.bin', 'expbert-features/train_7.bin', 'expbert-features/train_8.bin', 'expbert-features/train_9.bin'], dev_bin_file='
# ...
